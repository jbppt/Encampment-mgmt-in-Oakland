# %%
#import pandas 
import pandas as pd

# %%
#reading my csv file into jupyter notebook
df = pd.read_csv('Completed_Encampment_Management_Team_Operations_Since_2021.csv')
df.head()
# Out:
#   LOCATION;DISTRICT;SENSITIVITY ZONE;INTERVENTION;OPERATION START DATE;OPERATION END DATE  \
# 0  9th St and Pine St (cul-de-sac);D3;High;Deep C...
# 1  42nd & Dover;D1;High;Closure;March 28 2023;Mar...
# 2  42nd between MLK & Telegraph;D1;Low;Deep Clean...
# 3  Lake Merritt Park: 1200 Lakeshore;D2;High;Part...
# 4  West between 35th and 36th St;D3;Low;Deep Clea...
#
#   Unnamed: 1
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
#splitting my string into separate columns
df=df['LOCATION;DISTRICT;SENSITIVITY ZONE;INTERVENTION;OPERATION START DATE;OPERATION END DATE'].str.split(";", expand=True)
df
# Out:
#                                                0   1     2  \
# 0                9th St and Pine St (cul-de-sac)  D3  High
# 1                                   42nd & Dover  D1  High
# 2                   42nd between MLK & Telegraph  D1   Low
# 3              Lake Merritt Park: 1200 Lakeshore  D2  High
# 4                  West between 35th and 36th St  D3   Low
# ..                                           ...  ..   ...
# 673        Center St between 13th St and 14th St  D3  High
# 674           Mandela Pkwy between 13th and 14th  D3  High
# 675      13th St between Center and Mandela Pkwy  D3  High
# 676                        Cypress Memorial Park  D3  High
# 677  High St between Oakport St and Coliseum Way  D5   Low
#
#                                                      3              4  \
# 0                                        Deep Cleaning  March 30 2023
# 1                                              Closure  March 28 2023
# ...

# %%
#converting the dataframe into an excel file
df.to_excel("camp_mgmt.xlsx")
